# %%
from neo4j import GraphDatabase
import logging
from neo4j.exceptions import ServiceUnavailable
import time
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_parquet("pubmed_dump.parquet")
df_entit=pd.read_parquet('entities_09.parquet')
df=df.merge(df_entit,on='pmid',how='left')

df['author_list']=df['author_list'].apply(np.ndarray.tolist)
#TODO
df['keywords']=df['keywords'].fillna({i: np.array([]) for i in df.index}).apply(np.ndarray.tolist) 
df['disease']=df['disease'].fillna({i: np.array([]) for i in df.index}).apply(np.ndarray.tolist)
df['chemical']=df['chemical'].fillna({i: np.array([]) for i in df.index}).apply(np.ndarray.tolist)
df['organization']=df['organization'].fillna({i: np.array([]) for i in df.index}).apply(np.ndarray.tolist)
df['location']=df['location'].fillna({i: np.array([]) for i in df.index}).apply(np.ndarray.tolist)
df=df.sample(n=50)

# %%
df
# Out:
#          pmid                                              title  \
# 490  19793089  Histological structure and distribution of car...
# 615  17177685  Cytokines and soluble CD14 in breast milk in r...
# 68   31162024  Prevalence and clinical significance of koala ...
# 123  22551982  Expression and in vitro upregulation of MHCII ...
# 707  26713222  Evidence for horizontal gene transfer between ...
# 614  29412005  Citizen Science to Communicate about Public He...
# 291  34827969  An Analysis of Demographic and Triage Assessme...
# 593  26748912  Obstructive sleep apnoea in children with obesity
# 658   1537048  Retinal topography in the koala (Phascolarctos...
# 606   9765820  Lipopolysaccharide biosynthesis genes in koala...
# 746  20109750  Host-microbial interactions in childhood atopy...
# 510  25360252  Distribution models for koalas in South Austra...
# 852  28560934  Organic food consumption during pregnancy is a...
# 531   8894023  Proctitis associated with chlamydial infection...
# 839  29621315  Molecular evolution of DNMT1 in vertebrates: D...
# 621  17699831  Toll-like receptor 4 polymorphism associated w...
# 235  25925265  Induction of neutralizing antibodies specific ...
# 604  27078076  Japanese monkeys (Macaca fuscata) quickly dete...
# 765  32091701  Buruli Ulcer in Animals and Experimental Infec...
# 27   33915914  Toll-Like Receptor Expression Profiles in Koal...
# 172  15509709  Semen-induced luteal phase and identification ...
# 561   1807246  Serological assessment of chlamydial infection...
# 558  24974269  Four species of arboreal folivore show differe...
# 285   8771407  Histological and immunohistological study of t...
# 194  31310015  Predation by carpet pythons (Morelia spilota) ...
# 590  19530380  Barriers to the management of obesity in child...
# 557   7624512  Variation in reproductive parameters in the ca...
# 10   32556174  Helping koalas battle disease - Recent advance...
# 2    29382557  Koala immunology and infectious diseases: How ...
# 492  16727557  Seminal characteristics and spermatozoal morph...
# 795  22694899  Identification of diverse groups of endogenous...
# 511  28308521  Intraspecific variation in Eucalyptus secondar...
# 154  23527290  Preliminary characterisation of tumor necrosis...
# 661  12953323  Comparison of two intrauterine pressure cathet...
# 675  35127011  Testing the effectiveness of genetic monitorin...
# 284   9593650  Morphology of the thyroid in coastal and nonco...
# 337  26905635  Characterisation of CD4 T cells in healthy and...
# 916  28683749  Bidirectional associations between activity-re...
# 861  20659079  Fatty acids in breast milk and development of ...
# 706  21401954  Association between parenting practices and ch...
# 534   2818360  Haematological and biochemical reference value...
# 274  12649723  Comparative morphological study of the lingual...
# 375  23889092  Pharmacokinetics of fluconazole following intr...
# 418  24712170  Gastrointestinal torsions and intussusception ...
# 690  19761511  CD14 polymorphisms in mother and infant, solub...
# 188  19303079  Histopathological examination of the pancreas ...
# 31   35018700  Characterization of the juvenile koala gut mic...
# 788  10717949  Ultrastructural observations on in vivo fertil...
# 708  21737927  Growth inhibition and chromosomal instability ...
# 587   2246391  Lesions of toxoplasmosis in Australian marsupials
#
#                                               abstract  \
# 490  While the mandibular glands usually consist of...
# 615  Background:                    Conflicting evi...
# 68   Purpose:                    Koala retrovirus (...
# 123  Understanding and measuring immune activity of...
# 707  Chlamydia-infecting bacteriophages, members of...
# 614  There is a lack of research on how to communic...
# 291  In the 2019-2020 Australian bushfires, Kangaro...
# 593  Aims:                    The aim of this study...
# 658  Nissl-stained retinal wholemounts were used to...
# 606  We showed in 1988 that there are two strains o...
# 746  Background:                    Perturbations i...
# 510  The koala (Phascolarctos cinereus) occurs in t...
# 852  Objective:                    To find out how ...
# 531  Objective:                    To describe proc...
# 839  DNA methylation is mediated by a conserved fam...
# 621  We examined the association between haplotype ...
# 235  Background:                    The koala retro...
# 604  Humans quickly detect the presence of evolutio...
# 765  Skin lesions caused by Mycobacterium ulcerans ...
# 27   Toll-like receptors (TLRs), evolutionarily con...
# 172  The koala ovulates in response to mating. The ...
# 561  A rapid and simplified slide enzyme immunosorb...
# 558  The marsupials that eat Eucalyptus in south-ea...
# 285  The thymuses of 44 koalas, ranging from less t...
# 194  Koalas (Phascolarctos cinereus) are experienci...
# 590  Background:                    General practit...
# 557  Plasma androgen concentration was measured in ...
# 10   The iconic Australian marsupial, the koala (Ph...
# 2    Infectious diseases are contributing to the de...
# 492  Viable koala spermatozoa were successfully col...
# 795  A previous phylogenetic study suggested that m...
# 511  Traditional approaches to the question of the ...
# 154  Debilitating infectious diseases caused by Chl...
# 661  Objective:                    To compare the K...
# 675  Effective conservation requires accurate data ...
# 284  The gross morphology, histology, and ultrastru...
# 337  The koala (Phascolarctos cinereus) is an arbor...
# 916  Background:                    It has been gen...
# 861  Background:                    One of the expl...
# 706  Background:                    Insights into t...
# 534  Haematological and biochemical reference value...
# 274  The stereo structure of each lingual papilla o...
# 375  Clinically normal koalas (n = 12) received a s...
# 418  The recent classification as threatened status...
# 690  Different CD14 polymorphisms have been associa...
# 188  This retrospective study, which was based on k...
# 31   In this study we compared the faecal microbiom...
# 788  Information on the dynamics of gamete interact...
# 708  The DNA replication mechanism has been well es...
# 587  This report describes toxoplasmosis lesions in...
#
#                                               keywords  \
# 490                                                 []
# 615                                                 []
# 68   [Chlamydia pecorum, Phascolarctidae, South Aus...
# 123                                                 []
# 707  [gokushovirinae, horizontal gene transfer, mic...
# 614                                                 []
# 291  [Phascolarctidae, burn, mortality, rescue, tra...
# 593  [child, hypoventilation, obesity, sleep apnoea...
# 658                                                 []
# 606                                                 []
# 746                                                 []
# 510  [Citizen science, climate, ecological niche mo...
# 852  [and nutrition, food, Cohort studies, Diet, Fo...
# 531                                                 []
# 839                                                 []
# 621                                                 []
# 235                                                 []
# 604                                                 []
# 765                                                 []
# 27   [immune response, koala, koala retrovirus, tol...
# 172                                                 []
# 561                                                 []
# 558                                                 []
# 285                                                 []
# 194  [Koala, ecology, pathology, population managem...
# 590                                                 []
# 557                                                 []
# 10   [Chlamydia, Chlamydia pecorum, Phascolarctos c...
# 2    [Chlamydia, Immune system, Koala, Koala retrov...
# 492                                                 []
# 795                                                 []
# 511  [Deterrency, Eucalyptus, Key words Intraspecif...
# 154                                                 []
# 661                                                 []
# 675  [SNP, degradation, koala, monitoring, non‐inva...
# 284                                                 []
# 337  [CD4 T cell, Chlamydia, Koala, Monoclonal anti...
# 916  [Activity-related parenting practices, Bidirec...
# 861                                                 []
# 706                                                 []
# 534                                                 []
# 274                                                 []
# 375                                                 []
# 418                                                 []
# 690                                                 []
# 188                                                 []
# 31                                                  []
# 788                                                 []
# 708                                                 []
# 587                                                 []
#
#                                            author_list  \
# 490  [T Mizuno, A McKinnon, N Ichihara, T Amasaki, ...
# 615  [B E P Snijders, J G M C Damoiseaux, J Penders...
# 68   [Jessica Fabijan, Darren Miller, Olusola Olago...
# 123   [Quintin Lau, Paul J Canfield, Damien P Higgins]
# 707  [Anne G Rosenwald, Bradley Murray, Theodore To...
# 614  [Katrien De Cocker, Sebastien F M Chastin, Ils...
# 291  [Evie Dunstan, Oliver Funnell, Jenny McLelland...
# 593  [Rubina Kassim, Margaret-Anne Harris, Gary M L...
# 658  [K L Schmid, L M Schmid, C F Wildsoet, J D Pet...
# 606               [A A Girjes, F N Carrick, M F Lavin]
# 746  [John Penders, Carel Thijs, Monique Mommers, E...
# 510  [Ana M M Sequeira, Philip E J Roetman, Christo...
# 852  [Ana Paula Simões-Wüst, Carolina Moltó-Puigmar...
# 531                          [S Hemsley, P J Canfield]
# 839  [David Alvarez-Ponce, María Torres-Sánchez, Fe...
# 621  [Sander Banus, Renske W B Bottema, Christine L...
# 235  [Uwe Fiebig, Britta Dieckhoff, Christian Wurzb...
# 604                      [Nobuyuki Kawai, Hiroki Koda]
# 765                   [Miriam Bolz, Marie-Thérèse Ruf]
# 27   [Mohammad Enamul Hoque Kayesh, Md Abul Hashem,...
# 172  [S D Johnston, P O'Callaghan, K Nilsson, G Tzi...
# 561  [H Ueno, S Mizuno, I Takashima, R Osawa, W Bla...
# 558  [Lora M Jensen, Ian R Wallis, Karen J Marsh, B...
# 285                [P Canfield, S Hemsley, J Connolly]
# 194  [Amy Robbins, Joanne Loader, Deidre de Villier...
# 590  [Helen Dettori, Helen Elliott, Janette Horn, G...
# 557                [G M Cleva, G M Stone, R K Dickens]
# 10                     [Bonnie L Quigley, Peter Timms]
# 2    [Danielle Madden, Alessandra Whaite, Elizabeth...
# 492  [S D Johnston, M R McGowan, F N Carrick, R D C...
# 795  [Jie Cui, Gilda Tachedjian, Mary Tachedjian, E...
# 511  [I R Lawler, W J Foley, B M Eschler, D M Pass,...
# 154  [Marina Mathew, Kenneth W Beagley, Peter Timms...
# 661                                    [Mark A Dowdle]
# 675  [Anthony James Schultz, Kasha Strickland, Roma...
# 284                          [V J Lawson, F N Carrick]
# 337  [Chandan Mangar, Charles W Armitage, Peter Tim...
# 916  [Ester F C Sleddens, Jessica S Gubbels, Stef P...
# 861  [C Thijs, A Müller, L Rist, I Kummeling, B E P...
# 706  [Jessica S Gubbels, Stef P J Kremers, Annette ...
# 418              2014 Mar;45(1):118-26.  2014.0       []           []   None
# 690               2010 May;21(3):541-9.  2010.0       []           []   None
# 188             2009 May;140(4):217-24.  2009.0       []           []   None
# 31            2022 Sep;24(9):4209-4219.  2022.0       []           []   None
# 788               1999 Nov;7(4):307-20.  1999.0       []           []   None
# 708                 2011;75(7):1349-53.  2011.0       []           []   None
# 587             1990 Aug;103(2):159-67.  1990.0       []           []   None
#
#     disease genetic chemical
# 490      []    None       []
# 615      []    None       []
# 68       []    None       []
# 123      []    None       []
# 707      []    None       []
# 614      []    None       []
# 291      []    None       []
# 593      []    None       []
# 658      []    None       []
# 606      []    None       []
# 746      []    None       []
# 510      []    None       []
# 852      []    None       []
# 531      []    None       []
# 839      []    None       []
# 621      []    None       []
# 235      []    None       []
# 604      []    None       []
# 765      []    None       []
# 27       []    None       []
# 172      []    None       []
# 561      []    None       []
# 558      []    None       []
# 285      []    None       []
# 194      []    None       []
# 590      []    None       []
# 557      []    None       []
# 10       []    None       []
# 2        []    None       []
# 492      []    None       []
# 795      []    None       []
# 511      []    None       []
# 154      []    None       []
# 661      []    None       []
# 675      []    None       []
# 284      []    None       []
# 337      []    None       []
# 916      []    None       []
# 861      []    None       []
# 706      []    None       []
# 534      []    None       []
# 274      []    None       []
# 375      []    None       []
# 418      []    None       []
# 690      []    None       []
# 188      []    None       []
# 31       []    None       []
# 788      []    None       []
# 708      []    None       []
# 587      []    None       []

# %%
class NeoApp:

    def __init__(self, uri, user, password):
        self.driver = GraphDatabase.driver(uri, auth=(user, password))

    def close(self):
        # Don't forget to close the driver connection when you are finished with it
        self.driver.close()

    def create_friendship(self, person1_name, person2_name):
        with self.driver.session(database="neo4j") as session:
            # Write transactions allow the driver to handle retries and transient errors
            result = session.write_transaction(
                self._create_and_return_friendship, person1_name, person2_name)
            for row in result:
                print("Created friendship between: {p1}, {p2}".format(p1=row['p1'], p2=row['p2']))

    @staticmethod
    def _create_and_return_friendship(tx, person1_name, person2_name):
        # To learn more about the Cypher syntax, see https://neo4j.com/docs/cypher-manual/current/
        # The Reference Card is also a good resource for keywords https://neo4j.com/docs/cypher-refcard/current/
        query = (
            "CREATE (p1:Person { name: $person1_name }) "
            "CREATE (p2:Person { name: $person2_name }) "
            "CREATE (p1)-[:KNOWS]->(p2) "
            "RETURN p1, p2"
        )
        result = tx.run(query, person1_name=person1_name, person2_name=person2_name)
        try:
            return [{"p1": row["p1"]["name"], "p2": row["p2"]["name"]}
                    for row in result]
        # Capture any errors along with the query and data for traceability
        except ServiceUnavailable as exception:
            logging.error("{query} raised an error: \n {exception}".format(
                query=query, exception=exception))
            raise

    def find_person(self, person_name):
        with self.driver.session(database="neo4j") as session:
            result = session.read_transaction(self._find_and_return_person, person_name)
            for row in result:
                print("Found person: {row}".format(row=row))

    @staticmethod
    def _find_and_return_person(tx, person_name):
        query = (
            "MATCH (p:Person) "
            "WHERE p.name = $person_name "
            "RETURN p.name AS name"
        )
        result = tx.run(query, person_name=person_name)
        return [row["name"] for row in result]
        
    #@staticmethod
    def query(self, query, parameters=None, db=None):
        session = None
        response = None
        try: 
            session = self.driver.session(database=db) if db is not None else self.driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
uri = "neo4j+s://206c60f6.databases.neo4j.io"
user = "neo4j"
password = "Vo4n0Pi6yHb2no8cLAK2aoxGkRiUAwGKHJ8ApwgRHuQ"
neo_con = NeoApp(uri, user, password)

# %%
# Clean graph
query_str = """
    MATCH (n)
    DETACH DELETE n
    """
neo_con.query(query_str)
# Out:
# []

# %%
neo_con.query('CREATE CONSTRAINT papers IF NOT EXISTS ON (p:Paper)     ASSERT p.id IS UNIQUE')
neo_con.query('CREATE CONSTRAINT authors IF NOT EXISTS ON (a:Author) ASSERT a.name IS UNIQUE')
neo_con.query('CREATE CONSTRAINT categories IF NOT EXISTS ON (c:Category) ASSERT c.category IS UNIQUE')
# Out:
# []

# %%
# (Paper)
query = '''
        UNWIND $rows AS row
        MERGE (p:Paper {pmid:toInteger(row.pmid)})
        ON CREATE SET
        p.title = row.title,
        p.authors = row.author_list,
        p.keywords = row.keywords,
        p.diseases = row.disease,
        p.chemicals = row.chemical,
        p.locations = row.location,
        p.organizations = row.organization,
        p.date = toInteger(row.date),
        p.url = row.url
        RETURN count(*) as total
        '''
rows= df[['title','pmid','author_list','keywords','disease','chemical','location','organization','date','url']].to_dict('records')
neo_con.query(query, parameters = {'rows': rows})
# Out:
# [<Record total=50>]

# %% [markdown]
# query = '''
#         MATCH (p:Paper)
#         UNWIND p.diseases AS disease
#         WITH  disease, collect(p) AS papers
#         MERGE (d:Disease {name:disease})
#         WITH d, papers
#         UNWIND papers AS p
#         WITH d,p
#         MERGE (p)-[:ABOUT_DISEASE]->(d);
#         '''
# neo_con.query(query)
#
# query = '''
#         MATCH (p:Paper)
#         SET p.diseases = null
#         '''
# neo_con.query(query)

# %%
author_dic = {
    "node_type": "Author",
    "node_label": "a",
    "property_name": "authors",
    "rel_name": "AUTHORED",
}
chem_dic = {
    "node_type": "Chemical",
    "node_label": "c",
    "property_name": "chemicals",
    "rel_name": "ABOUT_CHEMICAL",
}
dis_dic = {
    "node_type": "Disease",
    "node_label": "d",
    "property_name": "diseases",
    "rel_name": "ABOUT_DISEASE",
}
gen_dic = {
    "node_type": "Genetic",
    "node_label": "g",
    "property_name": "genetics",
    "rel_name": "ABOUT_GENETIC",
}
loc_dic = {
    "node_type": "Location",
    "node_label": "l",
    "property_name": "locations",
    "rel_name": "HAS_LOCATION",
}
org_dic = {
    "node_type": "Organization",
    "node_label": "o",
    "property_name": "organizations",
    "rel_name": "HAS_ORG",
}
key_dic = {
    "node_type": "Keyword",
    "node_label": "k",
    "property_name": "keywords",
    "rel_name": "HAS_KEYWORD",
}
col_list=[author_dic, chem_dic, dis_dic, gen_dic, loc_dic, org_dic, key_dic]

# %%
for col in col_list:
    query = f'''
            MATCH (p:Paper)
            UNWIND p.{col["property_name"]} AS property
            WITH  property, collect(p) AS papers
            MERGE ({col["node_label"]}:{col["node_type"]} {{name:property}})
            WITH {col["node_label"]}, papers
            UNWIND papers AS p
            WITH {col["node_label"]},p
            MERGE (p)-[:{col["rel_name"]}]->({col["node_label"]});
            '''
    neo_con.query(query)

    query = f'''
            MATCH (p:Paper)
            SET p.{col["property_name"]} = null
            '''
    neo_con.query(query)
